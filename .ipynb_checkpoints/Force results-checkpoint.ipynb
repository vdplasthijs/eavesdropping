# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt

from ForceRNN import FRNN
# Out:
# [autoreload of ForceRNN failed: Traceback (most recent call last):
#   File "/home/thijs/.conda/envs/py37/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/thijs/.conda/envs/py37/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 450, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/thijs/.conda/envs/py37/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 387, in update_generic
#     update(a, b)
#   File "/home/thijs/.conda/envs/py37/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 357, in update_class
#     update_instances(old, new)
#   File "/home/thijs/.conda/envs/py37/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 312, in update_instances
#     update_instances(old, new, obj.__dict__, visited)
#   File "/home/thijs/.conda/envs/py37/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 317, in update_instances
#     update_instances(old, new, obj, visited)
#   File "/home/thijs/.conda/envs/py37/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 317, in update_instances
#     update_instances(old, new, obj, visited)
#   File "/home/thijs/.conda/envs/py37/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 315, in update_instances
#     if hasattr(obj, 'items') or (hasattr(obj, '__contains__')
# KeyboardInterrupt
# ]

# %%
frnn = FRNN(interval_w_update=4, n_gen=20, p_gg=0.3, 
            g_gg=1.5,
            fix_seed=None, alpha=1, tau=0.05, ode_tau=0.3)
signal = np.sin(np.linspace(0, 45, 600)) / 4
frnn.forward(f_est=signal)


plt.rcParams['figure.figsize'] = (12, 5)
# plt.subplot(1, 2, 1 )
# plt.plot(frnn.r_forw.T)
# plt.xlim([600, 630])

# plt.subplot(1, 2, 2)
plt.plot(frnn.time_array, frnn.z_forw.T)
plt.plot(frnn.time_array, frnn.f_full)
# plt.xlim([600, 730])
# plt.xlim([200, 800])
# Out:
# FRNN initiated

# %%
(frnn.weights['gz'] * frnn.z_forw[0]).shape
# Out:
# (100,)

# %%
plt.rcParams['figure.figsize'] = (18, 18)

for i_row in range(6):
    for i_col in range(6):
        plt.subplot(6, 6, 6 * i_row + i_col + 1)
        plt.plot(frnn.r_forw[i_row, 300:], frnn.r_forw[i_col, 300:])
        plt.title(f'x: {i_col}, y: {i_row}', weight='bold')
        
        
plt.suptitle('Phase plot all 6 r');
